# %%
import os
import pandas as pd
import re

# %%
#TODO Make a more dynamic path system later

nts_trip = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/trip_eul_2002-2023.tab"
nts_i = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/individual_eul_2002-2023.tab"
nts_vehicle = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/vehicle_eul_2002-2023.tab"
nts_household = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/household_eul_2002-2023.tab"
nts_psu = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/psu_eul_2002-2023.tab"
nts_day = "/home/trapfishscott/Cambridge24.25/Energy_thesis/Data/NTS_data/UKDA-5340-tab/tab/day_eul_2002-2023.tab"

# %%
# Load in vehicle df

vehicle_df = pd.read_csv(nts_vehicle, sep="\t",  dtype=str)
i_df = pd.read_csv(nts_i, sep="\t",  dtype=str)


# Load in PSID and Household
household_df = pd.read_csv(nts_household, sep="\t",  dtype=str)
psu_df = pd.read_csv(nts_psu, sep="\t",  dtype=str)

# Load in day
day_df = pd.read_csv(nts_day, sep="\t",  dtype=str)

# %%
# Nuisance columns

for df in [vehicle_df, i_df, household_df, psu_df, day_df]:
    df.drop(columns="SurveyYear", axis=1, inplace=True, errors="ignore")

# %%
# Load Trip DF and merging in chunks


chunksize = 100000

merged_chunks = []



for i,trip_df in enumerate(pd.read_csv(nts_trip, sep="\t", chunksize=chunksize, dtype=str)):
    # Filter by car only
    trip_df = trip_df[trip_df["MainMode_B04ID"] == "3"].sample(n=min(len(trip_df), 10000), random_state=42)
    chunk = trip_df.merge(i_df, on="IndividualID")
    chunk = chunk.merge(vehicle_df, on="VehicleID")
    chunk = chunk.merge(psu_df, on="PSUID")
    chunk.drop(columns=["PSUID", "HouseholdID"], axis=1, inplace=True, errors="ignore")
    chunk = chunk.merge(day_df, on="DayID")
    chunk.drop(columns="PSUID", axis=1, inplace=True, errors="ignore")
    chunk = chunk.merge(household_df, on="HouseholdID")
    merged_chunks.append(chunk)

    print(f"\rchunk: {i+1} complete!", end="", flush=True)

merged_df = pd.concat(merged_chunks, ignore_index=True)
# Out:
# chunk: 54 complete!

# %%
merged_df.to_pickle("/home/trapfishscott/Cambridge24.25/D200_ML_econ/ProblemSets/Project/data/merged_df.pkl")

# %%
merged_df = pd.read_pickle("/home/trapfishscott/Cambridge24.25/D200_ML_econ/ProblemSets/Project/data/merged_df.pkl")

# %%
# Taking small df for computational speed
merged_df_duplicate = merged_df.sample(1000)
print(f"Num columns: {len(merged_df_duplicate.columns)}")
# Out:
# Num columns: 465

# %%
merged_df_duplicate = merged_df_duplicate.T.drop_duplicates().T
print(f"Num columns: {len(merged_df_duplicate.columns)}")
# Out:
# Num columns: 407

# %%
# Finding extra columns

dupe_cols = set(merged_df.columns) - set(merged_df_duplicate.columns)

dupe_cols = list(dupe_cols)

# %%
merged_df_analysis = merged_df.drop(columns=dupe_cols, axis=1)

# %%
# For speed

merged_df_analysis = merged_df_analysis.sample(50000)

# %%
# Dealing with missing values

for col,missing_count in merged_df_analysis.isna().sum().items():
    if missing_count/len(merged_df_analysis) >= 0.001:
        print(f"{col}: {missing_count}")

# Trip start/ end are vital variables so we shall drop them

# TripStartHours: 7042
# TripStartMinutes: 7042
# TripStart: 7042
# TripEndHours: 7396
# TripEndMinutes: 7396
# TripEnd: 7396
# Out:
# TripStartHours: 667
# TripStartMinutes: 667
# TripStart: 667
# TripEndHours: 723
# TripEndMinutes: 723
# TripEnd: 723
# QLeaHous: 39316
# FarWalk: 34628
# DistWalk: 49976
# IntPlane: 11474
# DTJbYear: 37695
# ReNDNaM_B01ID: 34989
# CycMore_B01ID: 34989
# Cycle4w_B01ID: 34989
# ResMNCy_B01ID: 34989
# DVLALength: 8974
# VehAnMileage: 70
# VehComMile: 2175
# VehBusMile: 2175
# VehPriMile: 2175
# ReliaBus_B01ID: 1960
# FrqMetro_B01ID: 1960
# RelMetro_B01ID: 1960

# %%
vars_to_drop_na = ["TripStartHours", "TripStartMinutes", "TripStart", "TripEndHours", "TripEndMinutes", "TripEnd" ]

merged_df_analysis = merged_df_analysis.dropna(subset=vars_to_drop_na)

# %%
for col,missing_count in merged_df_analysis.isna().sum().items():
    if missing_count >= 0.1:
        print(f"{col}: {missing_count}")
# Out:
# QLeaHous: 38693
# FarWalk: 34031
# DistWalk: 49200
# IntPlane: 11389
# DTJbYear: 37110
# ReNDNaM_B01ID: 34480
# CycMore_B01ID: 34480
# Cycle4w_B01ID: 34480
# ResMNCy_B01ID: 34480
# IndividualID_y: 24
# DVLALength: 8819
# EngineCap: 39
# VehAnMileage: 69
# VehComMile: 2142
# VehBusMile: 2142
# VehPriMile: 2142
# ReliaBus_B01ID: 1910
# FrqMetro_B01ID: 1910
# RelMetro_B01ID: 1910

# %% [markdown]
# QLeaHous: 413346   -> "How many times did you leave the house yesterday - actual number"
# FarWalk: 363596 -> "Time last long walk took - minutes - actual time" # Has a banded version: "Time last long walk took - minutes - banded time"
#
# DistWalk: 523930 -> "Distance of last long walk - miles - actual distance", has a banded version
# IntPlane: 120431 -> "Number of international plane trips in last 12 months - actual number", has a banded version
# DTJbYear: 395771 -> "Date left last paid job - year element"
# SchAgeAcc: 524130 -> "Age first unaccompanied to school - actual age"
# ReNDNaM_B01ID: 366718 -> "Main reason do not drive"
# ReNDNbM_B01ID: 366718 -> "Main reason do not drive"
# CycMore_B01ID: 366718 -> "Amount of cycling compared to this time last year"
# Cycle4w_B01ID: 366718 -> "Whether ridden a bicycle during the last 4 weeks"
# ResMNCy_B01ID: 366718 -> "Main reason for not cycling more"
# DVLALength: 94114 -> "Vehicle length from the DVLA database - mm - actual length", contains a banded version
# VehComMile: 22566 -> "Annual vehicle commuting mileage - actual mileage", contains banded
# VehBusMile: 22562 -> "Annual vehicle business mileage - actual mileage", contains banded
# VehPriMile: 22566 -> "Annual vehicle private mileage - actual mileage", contains banded
#
# ---> Drop all

# %%
cols_to_drop_missing = [
    "QLeaHous",
    "FarWalk",
    "DistWalk",
    "IntPlane",
    "DTJbYear",
    "ReNDNaM_B01ID",
    "CycMore_B01ID",
    "Cycle4w_B01ID",
    "ResMNCy_B01ID",
    "DVLALength",
    "VehComMile",
    "VehBusMile",
    "VehPriMile"
]

merged_df_analysis = merged_df_analysis.drop(columns=cols_to_drop_missing, axis=1)

# %%
for col,missing_count in merged_df_analysis.isna().sum().items():
    if missing_count >= 1:
        print(f"{col}: {missing_count/len(merged_df_analysis)}")

# %% [markdown]
# EngineCap: 446
# VehAnMileage: 709
#
# dropping all nah

# %%
merged_df_analysis = merged_df_analysis.dropna()

# %%
merged_df_analysis = merged_df_analysis.copy()

# %%
merged_df_analysis.reset_index(drop=True, inplace=True)

# %%
merged_df_analysis
# Out:
#            TripID       DayID IndividualID_x HouseholdID_x     PSUID_x  \
# 0      2021032384  2021025751     2021003923    2021001660  2021000213
# 1      2014088419  2014041097     2014006347    2014002626  2014000260
# 2      2016166954  2016079072     2016012429    2016005183  2016000531
# 3      2009206076  2009092476     2009014322    2009006005  2009000445
# 4      2004164617  2004078912     2004011274    2004004679  2004000364
# ...           ...         ...            ...           ...         ...
# 47204  2016135357  2016064824     2016010121    2016004217  2016000431
# 47205  2013155558  2013082066     2013012679    2013005280  2013000450
# 47206  2006296663  2006146390     2006020913    2006008757  2006000649
# 47207  2007097569  2007047495     2007006785    2007002845  2007000207
# 47208  2002130527  2002072052     2002010294    2002004425  2002000351
#
#       PersNo_x TravDay_x JourSeq HowComp_B01ID SeriesCall_B01ID  ...  \
# 0            1         5       6             2                2  ...
# 1            2         7       3             2                2  ...
# 2            1         7       1             2                2  ...
# 3            1         6       4             2                2  ...
# 4            2         1       2             2                2  ...
# ...        ...       ...     ...           ...              ...  ...
# 47204        1         4       3             2                2  ...
# 47205        1         5       4             2                2  ...
# 47206        1         6       1             2                2  ...
# 47207        2         7       4             2                2  ...
# 47208        2         1       4             2                2  ...
#
#       HHIncQIS2005_B01ID HHIncQIS2005Eng_B01ID HHIncQIS2006_B01ID  \
# 0                    -10                   -10                -10
# 1                    -10                   -10                -10
# 2                    -10                   -10                -10
# 3                    -10                   -10                -10
# 4                    -10                   -10                -10
# ...                  ...                   ...                ...
# 47204                -10                   -10                -10
# 47205                -10                   -10                -10
# 47206                -10                   -10                  3
# 47207                -10                   -10                -10
# 47208                -10                   -10                -10
#
#       HHIncQDS2006_B01ID HHIncQIS2006Eng_B01ID HHIncQDS2006Eng_B01ID  \
# 0                    -10                   -10                   -10
# 1                    -10                   -10                   -10
# 2                    -10                   -10                   -10
# 3                    -10                   -10                   -10
# 4                    -10                   -10                   -10
# ...                  ...                   ...                   ...
# 47204                -10                   -10                   -10
# 47205                -10                   -10                   -10
# 47206                  3                     3                     3
# 47207                -10                   -10                   -10
# 47208                -10                   -10                   -10
#
#       HHIncQIS2007_B01ID HHIncQDS2007_B01ID HHIncQIS2007Eng_B01ID  \
# 0                    -10                -10                   -10
# 1                    -10                -10                   -10
# 2                    -10                -10                   -10
# 3                    -10                -10                   -10
# 4                    -10                -10                   -10
# ...                  ...                ...                   ...
# 47204                -10                -10                   -10
# 47205                -10                -10                   -10
# 47206                -10                -10                   -10
# 47207                  2                  2                     2
# 47208                -10                -10                   -10
#
#       HHIncQDS2007Eng_B01ID
# 0                       -10
# 1                       -10
# 2                       -10
# 3                       -10
# 4                       -10
# ...                     ...
# 47204                   -10
# 47205                   -10
# 47206                   -10
# 47207                     2
# 47208                   -10
#
# [47209 rows x 394 columns]

# %%
# Converting all to float

faulty_cols = []


for col in merged_df_analysis.columns:
    try:
        merged_df_analysis[col] = merged_df_analysis[col].astype(float)

    except:
        print(f"conversion did not work for {col}")
        faulty_cols.append(col)
# Out:
# conversion did not work for TripTravTime
# conversion did not work for JTTXSC
# conversion did not work for TWSDate
# conversion did not work for NumLicHolders

# %%
merged_df_analysis.drop(columns="TWSDate", axis=1, inplace=True, errors="ignore")

if "TWSDate" in faulty_cols:
    faulty_cols.remove("TWSDate")

faulty_cols
# Out:
# ['TripTravTime', 'JTTXSC', 'NumLicHolders']

# %%
faulty_indices = []

for index, row in merged_df_analysis[faulty_cols].iterrows():
    for col in faulty_cols:
        try:
            float(row[col])
        except:
            print(f"{row[col]} is faulty")
            faulty_indices.append(index)
# Out:
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty
#   is faulty

# %%
faulty_indices
# Out:
# [2609,
#  5726,
#  11608,
#  13003,
#  20663,
#  20663,
#  24613,
#  31721,
#  33024,
#  33113,
#  33976,
#  34283,
#  34945,
#  36116,
#  36116,
#  41915,
#  42769]

# %%
print(f"Length of df with faulty rows: {len(merged_df_analysis.iloc[faulty_indices, :])}")
# Out:
# Length of df with faulty rows: 17

# %% [markdown]
# empty " " are causing errors. As there are so few the best solution is to drop

# %%
merged_df_analysis = merged_df_analysis.drop(index=faulty_indices)

# %%
# Converting all to float


for col in merged_df_analysis.columns:
    merged_df_analysis[col] = merged_df_analysis[col].astype(float)

# %% [markdown]
# Succesfully converted everything to float

# %%
merged_df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47194 entries, 0 to 47208
# Columns: 393 entries, TripID to HHIncQDS2007Eng_B01ID
# dtypes: float64(393)
# memory usage: 141.9 MB

# %%
id_cols = ["TripID", "DayID", "HouseholdID_x", "PSUID_x", "SurveyYear"]

merged_df_analysis.drop(columns=id_cols, axis=1, inplace=True, errors="ignore")

# %%
# Exploring correlations
corr_matrix = merged_df_analysis.corr().abs()

# %%
# Print header
print(f"{'X':<25} {'Y':<25} {'Value':<10}")
print("="*60)

# Iterate through correlation matrix
for index, row in corr_matrix.iterrows():
    for col in corr_matrix.columns:
        if row[col] > 0.9 and index != col:  # Avoid self-correlations (Value = 1.0)
            print(f"{index:<25} {col:<25} {row[col]:<10.3f}")

# Start by dropping those with perfec correlation
# Out:
# X                         Y                         Value
# ============================================================
# IndividualID_x            VehicleID                 1.000
# IndividualID_x            IndividualID_y            1.000
# IndividualID_x            SurveyYear_B01ID          1.000
# IndividualID_x            TravelYear                0.999
# IndividualID_x            TWSYear                   0.999
# IndividualID_x            TWEYear                   0.999
# PersNo_x                  VehMainDriv_B01ID         0.905
# SeriesCall_B01ID          JJXSC                     1.000
# MainMode_B03ID            MainMode_B11ID            0.996
# MainMode_B11ID            MainMode_B03ID            0.996
# TripPurpose_B02ID         TripPurpose_B04ID         0.956
# TripPurpose_B04ID         TripPurpose_B02ID         0.956
# TripStartHours            TripStart                 0.998
# TripStartHours            TripStart_B01ID           1.000
# TripStartHours            TripStart_B02ID           0.993
# TripStartHours            TripEndHours              0.970
# TripStartHours            TripEnd                   0.982
# TripStartHours            TripEnd_B01ID             0.970
# TripStartHours            TripEnd_B02ID             0.971
# TripStart                 TripStartHours            0.998
# TripStart                 TripStart_B01ID           0.998
# TripStart                 TripStart_B02ID           0.995
# TripStart                 TripEndHours              0.971
# TripStart                 TripEnd                   0.983
# TripStart                 TripEnd_B01ID             0.971
# TripStart                 TripEnd_B02ID             0.972
# TripStart_B01ID           TripStartHours            1.000
# TripStart_B01ID           TripStart                 0.998
# TripStart_B01ID           TripStart_B02ID           0.993
# TripStart_B01ID           TripEndHours              0.970
# TripStart_B01ID           TripEnd                   0.982
# TripStart_B01ID           TripEnd_B01ID             0.970
# TripStart_B01ID           TripEnd_B02ID             0.971
# TripStart_B02ID           TripStartHours            0.993
# TripStart_B02ID           TripStart                 0.995
# TripStart_B02ID           TripStart_B01ID           0.993
# TripStart_B02ID           TripEndHours              0.966
# TripStart_B02ID           TripEnd                   0.978
# TripStart_B02ID           TripEnd_B01ID             0.966
# TripStart_B02ID           TripEnd_B02ID             0.976
# TripEndHours              TripStartHours            0.970
# TripEndHours              TripStart                 0.971
# TripEndHours              TripStart_B01ID           0.970
# TripEndHours              TripStart_B02ID           0.966
# TripEndHours              TripEnd                   0.987
# TripEndHours              TripEnd_B01ID             1.000
# TripEndHours              TripEnd_B02ID             0.993
# TripEnd                   TripStartHours            0.982
# TripEnd                   TripStart                 0.983
# TripEnd                   TripStart_B01ID           0.982
# TripEnd                   TripStart_B02ID           0.978
# TripEnd                   TripEndHours              0.987
# TripEnd                   TripEnd_B01ID             0.987
# TripEnd                   TripEnd_B02ID             0.986
# TripEnd_B01ID             TripStartHours            0.970
# TripEnd_B01ID             TripStart                 0.971
# TripEnd_B01ID             TripStart_B01ID           0.970
# TripEnd_B01ID             TripStart_B02ID           0.966
# TripEnd_B01ID             TripEndHours              1.000
# TripEnd_B01ID             TripEnd                   0.987
# TripEnd_B01ID             TripEnd_B02ID             0.993
# TripEnd_B02ID             TripStartHours            0.971
# TripEnd_B02ID             TripStart                 0.972
# TripEnd_B02ID             TripStart_B01ID           0.971
# TripEnd_B02ID             TripStart_B02ID           0.976
# TripEnd_B02ID             TripEndHours              0.993
# TripEnd_B02ID             TripEnd                   0.986
# TripEnd_B02ID             TripEnd_B01ID             0.993
# TripDisIncSW              TripDisExSW               1.000
# TripDisIncSW              JTTXSC                    0.902
# TripDisIncSW              JD                        1.000
# TripDisIncSW_B01ID        TripDisExSW_B01ID         1.000
# TripDisExSW               TripDisIncSW              1.000
# TripDisExSW               JTTXSC                    0.902
# TripDisExSW               JD                        1.000
# TripDisExSW_B01ID         TripDisIncSW_B01ID        1.000
# TripTotalTime             TripTravTime              0.972
# TripTotalTime             JOTXSC                    0.974
# TripTotalTime             JTTXSC                    0.956
# TripTotalTime_B01ID       TripTravTime_B01ID        0.981
# TripTravTime              TripTotalTime             0.972
# TripTravTime              JOTXSC                    0.969
# TripTravTime              JTTXSC                    0.987
# TripTravTime_B01ID        TripTotalTime_B01ID       0.981
# TripOrigGOR_B02ID         TripDestGOR_B02ID         0.979
# TripOrigGOR_B02ID         HHoldGOR_B02ID            0.978
# TripDestGOR_B02ID         TripOrigGOR_B02ID         0.979
# TripDestGOR_B02ID         HHoldGOR_B02ID            0.976
# JJXSC                     SeriesCall_B01ID          1.000
# JOTXSC                    TripTotalTime             0.974
# JOTXSC                    TripTravTime              0.969
# JOTXSC                    JTTXSC                    0.982
# JTTXSC                    TripDisIncSW              0.902
# JTTXSC                    TripDisExSW               0.902
# JTTXSC                    TripTotalTime             0.956
# JTTXSC                    TripTravTime              0.987
# JTTXSC                    JOTXSC                    0.982
# JTTXSC                    JD                        0.902
# JD                        TripDisIncSW              1.000
# JD                        TripDisExSW               1.000
# JD                        JTTXSC                    0.902
# W5                        W2                        0.913
# VehicleID                 IndividualID_x            1.000
# VehicleID                 IndividualID_y            1.000
# VehicleID                 SurveyYear_B01ID          1.000
# VehicleID                 TravelYear                0.999
# VehicleID                 TWSYear                   0.999
# VehicleID                 TWEYear                   0.999
# Interview_B01ID           BusDiffSum_B01ID          0.908
# Interview_B01ID           InterviewN_B01ID          0.989
# Interview_B01ID           EScooter_B01ID            0.993
# Interview_B01ID           PSUCountry_B01ID          0.906
# Age_B01ID                 Age_B04ID                 0.927
# Age_B04ID                 Age_B01ID                 0.927
# MarStat_B01ID             LiveWith_B02ID            0.903
# LiveWith_B02ID            MarStat_B01ID             0.903
# EdAttn1_B01ID             WalkTimeGroc_B01ID        0.990
# EdAttn1_B01ID             BusTimeGroc_B01ID         0.990
# OrdBusFreq_B01ID          PlaneFreq_B01ID           0.955
# CoachFreq_B01ID           TrainFreq_B01ID           0.988
# CoachFreq_B01ID           TaxiCabFreq_B01ID         0.987
# TrainFreq_B01ID           CoachFreq_B01ID           0.988
# TrainFreq_B01ID           TaxiCabFreq_B01ID         0.983
# TaxiCabFreq_B01ID         CoachFreq_B01ID           0.987
# TaxiCabFreq_B01ID         TrainFreq_B01ID           0.983
# PlaneFreq_B01ID           OrdBusFreq_B01ID          0.955
# OwnCycle_B01ID            Roads_B01ID               0.955
# OwnCycle_B01ID            PrivCar2_B01ID            0.950
# OwnCycle_B01ID            OrdBus2Freq_B01ID         0.935
# OwnCycle_B01ID            Coach2Freq_B01ID          0.953
# OwnCycle_B01ID            Train2Freq_B01ID          0.949
# OwnCycle_B01ID            TaxiCab2Freq_B01ID        0.949
# OwnCycle_B01ID            Plane2Freq_B01ID          0.954
# OwnCycle_B01ID            Walk2Freq_B01ID           0.927
# OwnCycle_B01ID            Ebike_B01ID               0.954
# OwnCycle_B01ID            OCSect_B01ID              0.938
# OwnCycle_B01ID            OwnCycleN_B01ID           0.950
# IntPlane_B01ID            PDrivSt_B01ID             0.930
# DrivDisable_B01ID         FootOut_B01ID             0.959
# PDrivSt_B01ID             IntPlane_B01ID            0.930
# PBlueBdg_B01ID            TravScW_B01ID             1.000
# PBlueBdg_B01ID            TravelDayType_B01ID       0.991
# PBlueBdg_B01ID            TravelDayTypeOld_B01ID    0.997
# PBlueBdg_B01ID            BlueBdg_B01ID             1.000
# DTJbMonth_B01ID           DTJbLong_B01ID            0.969
# DTJbLong_B01ID            DTJbMonth_B01ID           0.969
# EcoStat_B02ID             EcoStat_B03ID             0.971
# EcoStat_B03ID             EcoStat_B02ID             0.971
# WkHome_B01ID              PossHom_B01ID             0.965
# WkHome_B01ID              Educ_B01ID                0.965
# PossHom_B01ID             WkHome_B01ID              0.965
# PossHom_B01ID             Educ_B01ID                0.926
# PossTel_B01ID             PossComp_B01ID            0.998
# PossComp_B01ID            PossTel_B01ID             0.998
# MobDiffSum_B01ID          Accident_B01ID            0.984
# MobDiffSum_B01ID          TravDiffSum_B01ID         0.983
# BusDiffSum_B01ID          Interview_B01ID           0.908
# BusDiffSum_B01ID          InterviewN_B01ID          0.912
# BusDiffSum_B01ID          EScooter_B01ID            0.916
# BusDiffSum_B01ID          PSUCountry_B01ID          0.983
# BusDiffSum_B01ID          AddressType_B01ID         0.944
# BusDiffSum_B01ID          ResLength_B01ID           0.933
# TravScW_B01ID             PBlueBdg_B01ID            1.000
# TravScW_B01ID             TravelDayType_B01ID       0.992
# TravScW_B01ID             TravelDayTypeOld_B01ID    0.998
# TravScW_B01ID             BlueBdg_B01ID             0.999
# Roads_B01ID               OwnCycle_B01ID            0.955
# Roads_B01ID               PrivCar2_B01ID            0.995
# Roads_B01ID               OrdBus2Freq_B01ID         0.979
# Roads_B01ID               Coach2Freq_B01ID          0.999
# Roads_B01ID               Train2Freq_B01ID          0.994
# Roads_B01ID               TaxiCab2Freq_B01ID        0.995
# Roads_B01ID               Plane2Freq_B01ID          0.999
# Roads_B01ID               Walk2Freq_B01ID           0.971
# Roads_B01ID               Ebike_B01ID               0.999
# Roads_B01ID               OCSect_B01ID              0.983
# Roads_B01ID               OwnCycleN_B01ID           0.996
# Accident_B01ID            MobDiffSum_B01ID          0.984
# Accident_B01ID            TravDiffSum_B01ID         0.995
# Acc3Yr_B01ID              Acc12Mn_B01ID             0.998
# Acc12Mn_B01ID             Acc3Yr_B01ID              0.998
# FootOut_B01ID             DrivDisable_B01ID         0.959
# Educ_B01ID                WkHome_B01ID              0.965
# Educ_B01ID                PossHom_B01ID             0.926
# HowSch_B01ID              MarStN_B01ID              0.987
# PrivCar_B01ID             PrbJobN_B01ID             0.922
# PrivCar_B01ID             VehSatNavN_B01ID          0.918
# PrbJobN_B01ID             PrivCar_B01ID             0.922
# FdShp_B01ID               FdDel_B01ID               0.957
# FdShp_B01ID               FdFreq_B01ID              0.962
# FdDel_B01ID               FdShp_B01ID               0.957
# FdDel_B01ID               FdFreq_B01ID              0.989
# FdDel_B01ID               ShpEas_B01ID              0.952
# FdFreq_B01ID              FdShp_B01ID               0.962
# FdFreq_B01ID              FdDel_B01ID               0.989
# FdFreq_B01ID              ShpEas_B01ID              0.943
# ShpEas_B01ID              FdDel_B01ID               0.952
# ShpEas_B01ID              FdFreq_B01ID              0.943
# MarStN_B01ID              HowSch_B01ID              0.987
# CAccIdnt_B01ID            COB_B01ID                 0.976
# COB_B01ID                 CAccIdnt_B01ID            0.976
# MaritalS_B01ID            VehMakeModel_B02ID        0.908
# MaritalS_B01ID            CompanyCar_B02ID          0.912
# MaritalS_B01ID            WalkBus_B01ID             0.990
# MaritalS_B01ID            Getbus_B01ID              0.988
# MaritalS_B01ID            WalkRail_B01ID            0.984
# MaritalS_B01ID            BusRail_B01ID             0.976
# MaritalS_B01ID            DescTa_B01ID              0.991
# MaritalS_B01ID            ClosSta_B01ID             0.990
# MaritalS_B01ID            ShopOft_B01ID             0.988
# MaritalS_B01ID            DVShop_B01ID              0.989
# MaritalS_B01ID            BusStandard_B01ID         0.993
# MaritalS_B01ID            OnlineN_B01ID             0.994
# GenHeal_B01ID             HomeIUse_B01ID            0.992
# GenHeal_B01ID             OnGoIUse_B01ID            0.985
# GenHeal_B01ID             ElseIUse_B01ID            0.988
# GenHeal_B01ID             EdAttn4_B02ID             0.956
# GenHeal_B01ID             YNWkSAM_B01ID             0.997
# GenHeal_B01ID             PHVuse_B01ID              0.996
# GenHeal_B01ID             BikeTyp2_B01ID            0.957
# GenHeal_B01ID             TypeVcl3_B01ID            0.994
# GenHeal_B01ID             AutMan_B01ID              0.993
# HomeIUse_B01ID            GenHeal_B01ID             0.992
# HomeIUse_B01ID            OnGoIUse_B01ID            0.987
# HomeIUse_B01ID            ElseIUse_B01ID            0.988
# HomeIUse_B01ID            EdAttn4_B02ID             0.949
# HomeIUse_B01ID            YNWkSAM_B01ID             0.994
# HomeIUse_B01ID            PHVuse_B01ID              0.994
# HomeIUse_B01ID            BikeTyp2_B01ID            0.955
# HomeIUse_B01ID            TypeVcl3_B01ID            0.991
# HomeIUse_B01ID            AutMan_B01ID              0.990
# OnGoIUse_B01ID            GenHeal_B01ID             0.985
# OnGoIUse_B01ID            HomeIUse_B01ID            0.987
# OnGoIUse_B01ID            ElseIUse_B01ID            0.990
# OnGoIUse_B01ID            EdAttn4_B02ID             0.940
# OnGoIUse_B01ID            YNWkSAM_B01ID             0.985
# OnGoIUse_B01ID            PHVuse_B01ID              0.987
# OnGoIUse_B01ID            BikeTyp2_B01ID            0.948
# OnGoIUse_B01ID            TypeVcl3_B01ID            0.982
# OnGoIUse_B01ID            AutMan_B01ID              0.982
# ElseIUse_B01ID            GenHeal_B01ID             0.988
# ElseIUse_B01ID            HomeIUse_B01ID            0.988
# ElseIUse_B01ID            OnGoIUse_B01ID            0.990
# ElseIUse_B01ID            EdAttn4_B02ID             0.947
# ElseIUse_B01ID            YNWkSAM_B01ID             0.989
# ElseIUse_B01ID            PHVuse_B01ID              0.989
# ElseIUse_B01ID            BikeTyp2_B01ID            0.950
# ElseIUse_B01ID            TypeVcl3_B01ID            0.986
# ElseIUse_B01ID            AutMan_B01ID              0.985
# EdAttn4_B02ID             GenHeal_B01ID             0.956
# EdAttn4_B02ID             HomeIUse_B01ID            0.949
# EdAttn4_B02ID             OnGoIUse_B01ID            0.940
# EdAttn4_B02ID             ElseIUse_B01ID            0.947
# EdAttn4_B02ID             YNWkSAM_B01ID             0.960
# EdAttn4_B02ID             PHVuse_B01ID              0.958
# EdAttn4_B02ID             BikeTyp2_B01ID            0.923
# EdAttn4_B02ID             TypeVcl3_B01ID            0.958
# EdAttn4_B02ID             AutMan_B01ID              0.956
# NTrnsat_B01ID             RelTrain_B01ID            0.997
# NTrnsat_B01ID             FrqTrain_B01ID            0.996
# NTrnsat_B01ID             NSatServ_B01ID            0.980
# NTrnsat_B01ID             NReliBus_B01ID            0.959
# NTrnsat_B01ID             NFrqBus_B01ID             0.959
# NTrnsat_B01ID             SRNRdSat_B01ID            0.988
# NTrnsat_B01ID             LocRdSat_B01ID            0.988
# NTrnsat_B01ID             Ncyclane_B01ID            0.987
# NTrnsat_B01ID             WalkProv_B01ID            0.988
# RelTrain_B01ID            NTrnsat_B01ID             0.997
# RelTrain_B01ID            FrqTrain_B01ID            0.997
# RelTrain_B01ID            NSatServ_B01ID            0.980
# RelTrain_B01ID            NReliBus_B01ID            0.959
# RelTrain_B01ID            NFrqBus_B01ID             0.959
# RelTrain_B01ID            SRNRdSat_B01ID            0.988
# RelTrain_B01ID            LocRdSat_B01ID            0.988
# RelTrain_B01ID            Ncyclane_B01ID            0.987
# RelTrain_B01ID            WalkProv_B01ID            0.988
# FrqTrain_B01ID            NTrnsat_B01ID             0.996
# FrqTrain_B01ID            RelTrain_B01ID            0.997
# FrqTrain_B01ID            NSatServ_B01ID            0.979
# FrqTrain_B01ID            NReliBus_B01ID            0.958
# FrqTrain_B01ID            NFrqBus_B01ID             0.959
# FrqTrain_B01ID            SRNRdSat_B01ID            0.987
# FrqTrain_B01ID            LocRdSat_B01ID            0.987
# FrqTrain_B01ID            Ncyclane_B01ID            0.987
# FrqTrain_B01ID            WalkProv_B01ID            0.987
# NSatServ_B01ID            NTrnsat_B01ID             0.980
# NSatServ_B01ID            RelTrain_B01ID            0.980
# NSatServ_B01ID            FrqTrain_B01ID            0.979
# NSatServ_B01ID            NReliBus_B01ID            0.973
# NSatServ_B01ID            NFrqBus_B01ID             0.973
# NSatServ_B01ID            SRNRdSat_B01ID            0.982
# NSatServ_B01ID            LocRdSat_B01ID            0.982
# NSatServ_B01ID            Ncyclane_B01ID            0.982
# NSatServ_B01ID            WalkProv_B01ID            0.983
# NReliBus_B01ID            NTrnsat_B01ID             0.959
# NReliBus_B01ID            RelTrain_B01ID            0.959
# NReliBus_B01ID            FrqTrain_B01ID            0.958
# NReliBus_B01ID            NSatServ_B01ID            0.973
# NReliBus_B01ID            NFrqBus_B01ID             0.998
# NReliBus_B01ID            SRNRdSat_B01ID            0.962
# NReliBus_B01ID            LocRdSat_B01ID            0.963
# NReliBus_B01ID            Ncyclane_B01ID            0.963
# NReliBus_B01ID            WalkProv_B01ID            0.962
# NFrqBus_B01ID             NTrnsat_B01ID             0.959
# NFrqBus_B01ID             RelTrain_B01ID            0.959
# NFrqBus_B01ID             FrqTrain_B01ID            0.959
# NFrqBus_B01ID             NSatServ_B01ID            0.973
# NFrqBus_B01ID             NReliBus_B01ID            0.998
# NFrqBus_B01ID             SRNRdSat_B01ID            0.963
# NFrqBus_B01ID             LocRdSat_B01ID            0.963
# NFrqBus_B01ID             Ncyclane_B01ID            0.963
# NFrqBus_B01ID             WalkProv_B01ID            0.962
# SRNRdSat_B01ID            NTrnsat_B01ID             0.988
# SRNRdSat_B01ID            RelTrain_B01ID            0.988
# SRNRdSat_B01ID            FrqTrain_B01ID            0.987
# SRNRdSat_B01ID            NSatServ_B01ID            0.982
# SRNRdSat_B01ID            NReliBus_B01ID            0.962
# SRNRdSat_B01ID            NFrqBus_B01ID             0.963
# SRNRdSat_B01ID            LocRdSat_B01ID            0.993
# SRNRdSat_B01ID            Ncyclane_B01ID            0.989
# SRNRdSat_B01ID            WalkProv_B01ID            0.991
# LocRdSat_B01ID            NTrnsat_B01ID             0.988
# LocRdSat_B01ID            RelTrain_B01ID            0.988
# LocRdSat_B01ID            FrqTrain_B01ID            0.987
# LocRdSat_B01ID            NSatServ_B01ID            0.982
# LocRdSat_B01ID            NReliBus_B01ID            0.963
# LocRdSat_B01ID            NFrqBus_B01ID             0.963
# LocRdSat_B01ID            SRNRdSat_B01ID            0.993
# LocRdSat_B01ID            Ncyclane_B01ID            0.990
# LocRdSat_B01ID            WalkProv_B01ID            0.992
# Ncyclane_B01ID            NTrnsat_B01ID             0.987
# Ncyclane_B01ID            RelTrain_B01ID            0.987
# Ncyclane_B01ID            FrqTrain_B01ID            0.987
# Ncyclane_B01ID            NSatServ_B01ID            0.982
# Ncyclane_B01ID            NReliBus_B01ID            0.963
# Ncyclane_B01ID            NFrqBus_B01ID             0.963
# Ncyclane_B01ID            SRNRdSat_B01ID            0.989
# Ncyclane_B01ID            LocRdSat_B01ID            0.990
# Ncyclane_B01ID            WalkProv_B01ID            0.991
# WalkProv_B01ID            NTrnsat_B01ID             0.988
# WalkProv_B01ID            RelTrain_B01ID            0.988
# WalkProv_B01ID            FrqTrain_B01ID            0.987
# WalkProv_B01ID            NSatServ_B01ID            0.983
# WalkProv_B01ID            NReliBus_B01ID            0.962
# WalkProv_B01ID            NFrqBus_B01ID             0.962
# WalkProv_B01ID            SRNRdSat_B01ID            0.991
# WalkProv_B01ID            LocRdSat_B01ID            0.992
# WalkProv_B01ID            Ncyclane_B01ID            0.991
# YNWkSAM_B01ID             GenHeal_B01ID             0.997
# YNWkSAM_B01ID             HomeIUse_B01ID            0.994
# YNWkSAM_B01ID             OnGoIUse_B01ID            0.985
# YNWkSAM_B01ID             ElseIUse_B01ID            0.989
# YNWkSAM_B01ID             EdAttn4_B02ID             0.960
# YNWkSAM_B01ID             PHVuse_B01ID              0.998
# Ebike_B01ID               OCSect_B01ID              0.983
# Ebike_B01ID               OwnCycleN_B01ID           0.996
# LackComp_B01ID            LeftOut_B01ID             0.998
# LackComp_B01ID            Isolated_B01ID            0.998
# LackComp_B01ID            Lonely_B01ID              0.991
# LeftOut_B01ID             LackComp_B01ID            0.998
# LeftOut_B01ID             Isolated_B01ID            0.999
# LeftOut_B01ID             Lonely_B01ID              0.992
# Isolated_B01ID            LackComp_B01ID            0.998
# Isolated_B01ID            LeftOut_B01ID             0.999
# Isolated_B01ID            Lonely_B01ID              0.992
# Lonely_B01ID              LackComp_B01ID            0.991
# Lonely_B01ID              LeftOut_B01ID             0.992
# Lonely_B01ID              Isolated_B01ID            0.992
# OCSect_B01ID              OwnCycle_B01ID            0.938
# OCSect_B01ID              Roads_B01ID               0.983
# OCSect_B01ID              PrivCar2_B01ID            0.978
# OCSect_B01ID              OrdBus2Freq_B01ID         0.964
# OCSect_B01ID              Coach2Freq_B01ID          0.982
# OCSect_B01ID              Train2Freq_B01ID          0.977
# OCSect_B01ID              TaxiCab2Freq_B01ID        0.978
# OCSect_B01ID              Plane2Freq_B01ID          0.982
# OCSect_B01ID              Walk2Freq_B01ID           0.955
# OCSect_B01ID              Ebike_B01ID               0.983
# OCSect_B01ID              OwnCycleN_B01ID           0.979
# OwnCycleN_B01ID           OwnCycle_B01ID            0.950
# OwnCycleN_B01ID           Roads_B01ID               0.996
# OwnCycleN_B01ID           PrivCar2_B01ID            0.991
# OwnCycleN_B01ID           OrdBus2Freq_B01ID         0.974
# OwnCycleN_B01ID           Coach2Freq_B01ID          0.995
# OwnCycleN_B01ID           Train2Freq_B01ID          0.991
# OwnCycleN_B01ID           TaxiCab2Freq_B01ID        0.991
# OwnCycleN_B01ID           Plane2Freq_B01ID          0.995
# OwnCycleN_B01ID           Walk2Freq_B01ID           0.969
# OwnCycleN_B01ID           Ebike_B01ID               0.996
# OwnCycleN_B01ID           OCSect_B01ID              0.979
# InterviewN_B01ID          Interview_B01ID           0.989
# InterviewN_B01ID          BusDiffSum_B01ID          0.912
# InterviewN_B01ID          EScooter_B01ID            0.996
# InterviewN_B01ID          PSUCountry_B01ID          0.909
# EScooter_B01ID            Interview_B01ID           0.993
# EScooter_B01ID            BusDiffSum_B01ID          0.916
# EScooter_B01ID            InterviewN_B01ID          0.996
# EScooter_B01ID            PSUCountry_B01ID          0.913
# ES2020_B01ID              F2FPhone_B01ID            0.981
# MaritalStat_B01ID         HHIncQDS2023Eng_B01ID     0.982
# TravDiffSum_B01ID         MobDiffSum_B01ID          0.983
# TravDiffSum_B01ID         Accident_B01ID            0.995
# IndividualID_y            IndividualID_x            1.000
# IndividualID_y            VehicleID                 1.000
# IndividualID_y            SurveyYear_B01ID          1.000
# IndividualID_y            TravelYear                0.999
# IndividualID_y            TWSYear                   0.999
# IndividualID_y            TWEYear                   0.999
# VehMainDriv_B01ID         PersNo_x                  0.905
# VehMakeModel_B02ID        MaritalS_B01ID            0.908
# VehMakeModel_B02ID        WalkBus_B01ID             0.910
# VehMakeModel_B02ID        Getbus_B01ID              0.904
# VehMakeModel_B02ID        WalkRail_B01ID            0.904
# VehMakeModel_B02ID        DescTa_B01ID              0.911
# VehMakeModel_B02ID        ClosSta_B01ID             0.909
# VehMakeModel_B02ID        ShopOft_B01ID             0.909
# VehMakeModel_B02ID        DVShop_B01ID              0.909
# VehMakeModel_B02ID        BusStandard_B01ID         0.913
# VehMakeModel_B02ID        OnlineN_B01ID             0.913
# VehWeekMileage_B01ID      VehEligMileage_B01ID      0.994
# VehEligMileage_B01ID      VehWeekMileage_B01ID      0.994
# VehMilesOutGB_B01ID       VehPurpOutGB_B01ID        0.967
# VehPurpOutGB_B01ID        VehMilesOutGB_B01ID       0.967
# VehRank_B01ID             NumCarVan_B02ID           0.907
# CompanyCar_B02ID          MaritalS_B01ID            0.912
# CompanyCar_B02ID          WalkBus_B01ID             0.910
# CompanyCar_B02ID          Getbus_B01ID              0.915
# CompanyCar_B02ID          WalkRail_B01ID            0.905
# CompanyCar_B02ID          DescTa_B01ID              0.913
# CompanyCar_B02ID          ClosSta_B01ID             0.912
# CompanyCar_B02ID          ShopOft_B01ID             0.910
# CompanyCar_B02ID          DVShop_B01ID              0.911
# CompanyCar_B02ID          BusStandard_B01ID         0.914
# CompanyCar_B02ID          OnlineN_B01ID             0.916
# VehBusMile_B01ID          VehPriMile_B01ID          0.919
# VehPriMile_B01ID          VehBusMile_B01ID          0.919
# VehSatNav_B01ID           HHIncQDS2008_B01ID        0.994
# VehSatNav_B01ID           HHIncQDS2008Eng_B01ID     0.929
# VehSatNav_B01ID           HHIncQIS2008Eng_B01ID     0.930
# VehSatNavN_B01ID          PrivCar_B01ID             0.918
# BikeTyp2_B01ID            GenHeal_B01ID             0.957
# BikeTyp2_B01ID            HomeIUse_B01ID            0.955
# BikeTyp2_B01ID            OnGoIUse_B01ID            0.948
# BikeTyp2_B01ID            ElseIUse_B01ID            0.950
# BikeTyp2_B01ID            EdAttn4_B02ID             0.923
# BikeTyp2_B01ID            YNWkSAM_B01ID             0.960
# BikeTyp2_B01ID            PHVuse_B01ID              0.959
# BikeTyp2_B01ID            TypeVcl3_B01ID            0.962
# BikeTyp2_B01ID            AutMan_B01ID              0.949
# TypeVcl3_B01ID            GenHeal_B01ID             0.994
# TypeVcl3_B01ID            HomeIUse_B01ID            0.991
# TypeVcl3_B01ID            OnGoIUse_B01ID            0.982
# TypeVcl3_B01ID            ElseIUse_B01ID            0.986
# TypeVcl3_B01ID            EdAttn4_B02ID             0.958
# TypeVcl3_B01ID            YNWkSAM_B01ID             0.997
# TypeVcl3_B01ID            PHVuse_B01ID              0.995
# TypeVcl3_B01ID            BikeTyp2_B01ID            0.962
# TypeVcl3_B01ID            AutMan_B01ID              0.990
# AutMan_B01ID              GenHeal_B01ID             0.993
# AutMan_B01ID              HomeIUse_B01ID            0.990
# AutMan_B01ID              OnGoIUse_B01ID            0.982
# AutMan_B01ID              ElseIUse_B01ID            0.985
# AutMan_B01ID              EdAttn4_B02ID             0.956
# AutMan_B01ID              YNWkSAM_B01ID             0.996
# AutMan_B01ID              PHVuse_B01ID              0.994
# AutMan_B01ID              BikeTyp2_B01ID            0.949
# AutMan_B01ID              TypeVcl3_B01ID            0.990
# SurveyYear_B01ID          IndividualID_x            1.000
# SurveyYear_B01ID          VehicleID                 1.000
# SurveyYear_B01ID          IndividualID_y            1.000
# SurveyYear_B01ID          TravelYear                0.999
# SurveyYear_B01ID          TWSYear                   0.999
# SurveyYear_B01ID          TWEYear                   0.999
# PSUCountry_B01ID          Interview_B01ID           0.906
# PSUCountry_B01ID          BusDiffSum_B01ID          0.983
# PSUCountry_B01ID          InterviewN_B01ID          0.909
# PSUCountry_B01ID          EScooter_B01ID            0.913
# PSUCountry_B01ID          AddressType_B01ID         0.942
# PSUCountry_B01ID          ResLength_B01ID           0.928
# TravelYear                IndividualID_x            0.999
# TravelYear                VehicleID                 0.999
# TravelYear                IndividualID_y            0.999
# TravelYear                SurveyYear_B01ID          0.999
# TravelYear                TWSYear                   1.000
# TravelYear                TWEYear                   1.000
# TravelWeekDay_B02ID       TravelWeekDay_B03ID       0.931
# TravelWeekDay_B03ID       TravelWeekDay_B02ID       0.931
# TravelDayType_B01ID       PBlueBdg_B01ID            0.991
# TravelDayType_B01ID       TravScW_B01ID             0.992
# TravelDayType_B01ID       TravelDayTypeOld_B01ID    0.989
# TravelDayType_B01ID       BlueBdg_B01ID             0.991
# TravelDayTypeOld_B01ID    PBlueBdg_B01ID            0.997
# TravelDayTypeOld_B01ID    TravScW_B01ID             0.998
# TravelDayTypeOld_B01ID    TravelDayType_B01ID       0.989
# TravelDayTypeOld_B01ID    BlueBdg_B01ID             0.997
# TWSMonth                  TWSWeek                   0.996
# TWSMonth                  TWEMonth                  0.939
# TWSMonth                  TWEWeek                   0.938
# TWSYear                   IndividualID_x            0.999
# TWSYear                   VehicleID                 0.999
# TWSYear                   IndividualID_y            0.999
# TWSYear                   SurveyYear_B01ID          0.999
# TWSYear                   TravelYear                1.000
# TWSYear                   TWEYear                   1.000
# TWSWeek                   TWSMonth                  0.996
# TWSWeek                   TWEMonth                  0.938
# TWSWeek                   TWEWeek                   0.938
# TWEMonth                  TWSMonth                  0.939
# TWEMonth                  TWSWeek                   0.938
# TWEMonth                  TWEWeek                   0.996
# TWEYear                   IndividualID_x            0.999
# TWEYear                   VehicleID                 0.999
# TWEYear                   IndividualID_y            0.999
# TWEYear                   SurveyYear_B01ID          0.999
# TWEYear                   TravelYear                1.000
# TWEYear                   TWSYear                   1.000
# TWEWeek                   TWSMonth                  0.938
# TWEWeek                   TWSWeek                   0.938
# TWEWeek                   TWEMonth                  0.996
# AddressType_B01ID         BusDiffSum_B01ID          0.944
# AddressType_B01ID         PSUCountry_B01ID          0.942
# ResLength_B01ID           BusDiffSum_B01ID          0.933
# ResLength_B01ID           PSUCountry_B01ID          0.928
# HHoldGOR_B02ID            TripOrigGOR_B02ID         0.978
# HHoldGOR_B02ID            TripDestGOR_B02ID         0.976
# HHoldCountry_B01ID        HHIncQDSEngTS_B01ID       0.900
# HHoldCountry_B01ID        HHIncQISEngTS_B01ID       0.900
# HRPSEGWorkStat_B01ID      F2FPhone_B01ID            0.909
# NumCarVan                 NumVehicles               0.948
# NumCarVan_B02ID           VehRank_B01ID             0.907
# NumVehicles               NumCarVan                 0.948
# WalkBus_B01ID             MaritalS_B01ID            0.990
# WalkBus_B01ID             VehMakeModel_B02ID        0.910
# WalkBus_B01ID             CompanyCar_B02ID          0.910
# WalkBus_B01ID             Getbus_B01ID              0.987
# WalkBus_B01ID             WalkRail_B01ID            0.987
# WalkBus_B01ID             BusRail_B01ID             0.978
# WalkBus_B01ID             DescTa_B01ID              0.993
# WalkBus_B01ID             ClosSta_B01ID             0.992
# WalkBus_B01ID             ShopOft_B01ID             0.989
# WalkBus_B01ID             DVShop_B01ID              0.990
# WalkBus_B01ID             BusStandard_B01ID         0.997
# WalkBus_B01ID             OnlineN_B01ID             0.995
# Getbus_B01ID              MaritalS_B01ID            0.988
# Getbus_B01ID              VehMakeModel_B02ID        0.904
# Getbus_B01ID              CompanyCar_B02ID          0.915
# Getbus_B01ID              WalkBus_B01ID             0.987
# Getbus_B01ID              WalkRail_B01ID            0.979
# Getbus_B01ID              BusRail_B01ID             0.973
# Getbus_B01ID              DescTa_B01ID              0.989
# Getbus_B01ID              ClosSta_B01ID             0.988
# Getbus_B01ID              ShopOft_B01ID             0.987
# Getbus_B01ID              DVShop_B01ID              0.987
# Getbus_B01ID              BusStandard_B01ID         0.989
# Getbus_B01ID              OnlineN_B01ID             0.993
# FrqBus_B01ID              ReliaBus_B01ID            0.900
# ReliaBus_B01ID            FrqBus_B01ID              0.900
# ReliaBus_B01ID            RelMetro_B01ID            0.938
# WalkRail_B01ID            MaritalS_B01ID            0.984
# WalkRail_B01ID            VehMakeModel_B02ID        0.904
# WalkRail_B01ID            CompanyCar_B02ID          0.905
# WalkRail_B01ID            WalkBus_B01ID             0.987
# WalkRail_B01ID            Getbus_B01ID              0.979
# WalkRail_B01ID            BusRail_B01ID             0.987
# WalkRail_B01ID            DescTa_B01ID              0.986
# WalkRail_B01ID            ClosSta_B01ID             0.984
# WalkRail_B01ID            ShopOft_B01ID             0.983
# WalkRail_B01ID            DVShop_B01ID              0.984
# WalkRail_B01ID            BusStandard_B01ID         0.989
# WalkRail_B01ID            OnlineN_B01ID             0.989
# BusRail_B01ID             MaritalS_B01ID            0.976
# BusRail_B01ID             WalkBus_B01ID             0.978
# BusRail_B01ID             Getbus_B01ID              0.973
# BusRail_B01ID             WalkRail_B01ID            0.987
# BusRail_B01ID             DescTa_B01ID              0.978
# BusRail_B01ID             ClosSta_B01ID             0.977
# BusRail_B01ID             ShopOft_B01ID             0.975
# BusRail_B01ID             DVShop_B01ID              0.975
# BusRail_B01ID             BusStandard_B01ID         0.981
# BusRail_B01ID             OnlineN_B01ID             0.981
# DescTa_B01ID              MaritalS_B01ID            0.991
# DescTa_B01ID              VehMakeModel_B02ID        0.911
# DescTa_B01ID              CompanyCar_B02ID          0.913
# DescTa_B01ID              WalkBus_B01ID             0.993
# HTrWalk_B01ID
# OwnCycle_B01ID
# Cycle12_B01ID
# CycRoute_B01ID
# IntPlane_B01ID
# CarPass_B01ID
# DrivLic_B02ID
# DrivExp_B01ID
# CarAccess_B01ID
# CarAccess_B02ID
# DrivDisable_B01ID
# LastDr_B01ID
# PDrivSt_B01ID
# ResNDrM_B01ID
# PBlueBdg_B01ID
# IndIncome2002_B02ID
# DTJbMonth_B01ID
# DTJbLong_B01ID
# WkPlace_B01ID
# IndWkGOR_B02ID
# EcoStat_B02ID
# EcoStat_B03ID
# ES2000_B01ID
# ES2010_B01ID
# NSSec_B03ID
# SC_B01ID
# Stat_B01ID
# SVise_B01ID
# WkMode_B01ID
# ParkWk_B01ID
# CarWM_B01ID
# OthWM_B01ID
# WkHome_B01ID
# PossHom_B01ID
# OftHome_B01ID
# PossTel_B01ID
# PossComp_B01ID
# TravSh_B01ID
# CarSM_B01ID
# OthSM_B01ID
# MobDiffSum_B01ID
# FootDiffSum_B01ID
# BusDiffSum_B01ID
# OthDis_B01ID
# PowWhl_B01ID
# PowWhUse_B01ID
# MobScUse_B01ID
# TravScW_B01ID
# Roads_B01ID
# Accident_B01ID
# Acc3Yr_B01ID
# Acc12Mn_B01ID
# FootOut_B01ID
# BusOut_B01ID
# Educ_B01ID
# EducFT_B01ID
# EducN_B01ID
# HowSch_B01ID
# PrivCar_B01ID
# PrbJobN_B01ID
# WkLift_B01ID
# WkMuch_B01ID
# CarsEas_B01ID
# FdShp_B01ID
# FdDel_B01ID
# FdFreq_B01ID
# DelStrt_B01ID
# ShpEas_B01ID
# MarStN_B01ID
# PossHmN_B01ID
# CAccIdnt_B01ID
# COB_B01ID
# ShpTroN_B01ID
# EligPass_B01ID
# TicketHolding_B01ID
# MaritalS_B01ID
# RsMnCyA_B01ID
# RsMnCyB_B01ID
# GenHeal_B01ID
# HomeIUse_B01ID
# OnGoIUse_B01ID
# ElseIUse_B01ID
# PracNec_B01ID
# LivCit_B01ID
# EdAttn4_B02ID
# NTrnsat_B01ID
# RelTrain_B01ID
# FrqTrain_B01ID
# NSatServ_B01ID
# NReliBus_B01ID
# NFrqBus_B01ID
# SRNRdSat_B01ID
# LocRdSat_B01ID
# Ncyclane_B01ID
# WalkProv_B01ID
# YNWkSAM_B01ID
# PHVuse_B01ID
# PHVFreq_B01ID
# OwnPhone_B01ID
# SmPhUse_B01ID
# Bicycle2_B01ID
# SENo2_B01ID
# LeRidCy_B01ID
# YNCy2AM_B01ID
# YNCy2BM_B01ID
# YNCy2M_B01ID
# EncCycM_B01ID
# YNWlkAM_B01ID
# YNWlkBM_B01ID
# YNWlkM_B01ID
# EncWkM_B01ID
# Carer_B01ID
# Caretime_B01ID
# PrivCar2_B01ID
# OrdBus2Freq_B01ID
# Coach2Freq_B01ID
# Train2Freq_B01ID
# TaxiCab2Freq_B01ID
# Plane2Freq_B01ID
# Walk2Freq_B01ID
# Ebike_B01ID
# Bicycle3Freq_B01ID
# PHVFreq2_B01ID
# LackComp_B01ID
# LeftOut_B01ID
# Isolated_B01ID
# Lonely_B01ID
# OCSect_B01ID
# OcPbSect_B01ID
# OwnCycleN_B01ID
# InterviewN_B01ID
# EScooter_B01ID
# EScooterFreq_B01ID
# ES2020_B01ID
# MaritalStat_B01ID
# TravDiffSum_B01ID
# IndividualID_y
# VehMainDriv_B01ID
# VehAvail_B01ID
# VehType_B03ID
# VehMakeModel_B02ID
# DVLALengthBand_B01ID
# VehAge_B01ID
# VehPropTypeTS_B01ID
# EngineCap_B01ID
# EngineCap_B02ID
# VehCO2Tax2008_B01ID
# VehAnMileage_B01ID
# VehTotMileage_B01ID
# VehWeekMileage_B01ID
# VehInelMileage_B01ID
# VehInelReason_B01ID
# VehEligMileage_B01ID
# VehMilesOutGB_B01ID
# VehPurpOutGB_B01ID
# VehRank_B01ID
# CompanyCar_B02ID
# WhyVehNotUsed_B01ID
# WhyVehNotUsed_B02ID
# VehComMile_B01ID
# VehBusMile_B01ID
# VehPriMile_B01ID
# VehParkLoc_B01ID
# CarOwn_B01ID
# VehSatNav_B01ID
# VehSatNavN_B01ID
# BikeTyp2_B01ID
# TypeVcl3_B01ID
# AutMan_B01ID
# VehCO2Bands_B01ID
# SurveyYear_B01ID
# PSUGOR_B02ID
# PSUStatsReg_B01ID
# PSUCountry_B01ID
# TravelWeekDay_B01ID
# TravelWeekDay_B02ID
# TravelWeekDay_B03ID
# TravelDayType_B01ID
# TravelDayTypeOld_B01ID
# TWSWeekday_B01ID
# TWEWeekday_B01ID
# QuotaMonth_B01ID
# HHIncome2002_B02ID
# HHIncOrig_B01ID
# AddressType_B01ID
# Ten1_B02ID
# ResLength_B01ID
# HHoldGOR_B02ID
# HHoldCountry_B01ID
# HHoldStruct_B02ID
# HRPWorkStat_B02ID
# HRPEmpStat_B01ID
# HRPSEGWorkStat_B01ID
# HHoldEmploy_B01ID
# NumCarVan_B02ID
# HHoldCVAvail_B01ID
# WalkBus_B01ID
# Getbus_B01ID
# FrqBus_B01ID
# ReliaBus_B01ID
# SatServ_B01ID
# WalkRail_B01ID
# BusRail_B01ID
# DescTa_B01ID
# FrqMetro_B01ID
# RelMetro_B01ID
# ClosSta_B01ID
# WalkRailAlt_B01ID
# BusRailAlt_B01ID
# JTimeGP_B01ID
# JTimeChem_B01ID
# JTimeHosp_B01ID
# JTimeShopC_B01ID
# JTimeGroc_B01ID
# JTimePost_B01ID
# JTimePrimSch_B01ID
# JTimeSecSch_B01ID
# JTimeColl_B01ID
# Deliv_B01ID
# HowOrd_B01ID
# HowB_B01ID
# ShopOft_B01ID
# DVShop_B01ID
# BlueBdg_B01ID
# Settlement2011EW_B03ID
# Settlement2011EW_B04ID
# Online_B01ID
# TrainSat_B01ID
# DelMeth_B01ID
# DelVisit_B01ID
# Howspec_B01ID
# TravSpec_B01ID
# HowBN_B01ID
# Pavement_B01ID
# CycLane_B01ID
# DelMethN_B01ID
# BusStandard_B01ID
# OnlineN_B01ID
# SelPer_B01ID
# HHoldFdShp_B01ID
# HHoldFdFreq_B01ID
# HHoldOAClass2011_B03ID
# Landlord_B01ID
# F2FPhone_B01ID
# HHIncQDS2008_B01ID
# HHIncQDS2008Eng_B01ID
# HHIncQIS2008Eng_B01ID
# HHIncQDS2009_B01ID
# HHIncQDS2009Eng_B01ID
# HHIncQIS2009Eng_B01ID
# HHIncQDS2010_B01ID
# HHIncQDS2010Eng_B01ID
# HHIncQDS2011_B01ID
# HHIncQDS2011Eng_B01ID
# HHIncQDS2012_B01ID
# HHIncQDS2012Eng_B01ID
# HHIncQDS2013Eng_B01ID
# HHIncQIS2013Eng_B01ID
# HHIncQDS2014Eng_B01ID
# HHIncQDS2015Eng_B01ID
# HHIncQDS2016Eng_B01ID
# HHIncQDS2017Eng_B01ID
# HHIncQDS2018Eng_B01ID
# HHIncQDS2019Eng_B01ID
# HHIncQDS2020Eng_B01ID
# HHIncQDS2021Eng_B01ID
# HHIncQDS2022Eng_B01ID
# HHIncQDS2023Eng_B01ID
# HHIncQDSEngTS_B01ID
# HHIncQISEngTS_B01ID
# WalkTimeGP_B01ID
# BusTimeGP_B01ID
# WalkTimePO_B01ID
# BusTimePO_B01ID
# WalkTimeChem_B01ID
# BusTimeChem_B01ID
# WalkTimeGroc_B01ID
# BusTimeGroc_B01ID
# WalkTimeShopC_B01ID
# BusTimeShopC_B01ID
# WalkTimeHosp_B01ID
# BusTimeHosp_B01ID
# HHIncQIS2002_B01ID
# HHIncQIS2002Eng_B01ID
# HHIncQIS2003_B01ID
# HHIncQIS2003Eng_B01ID
# HHIncQIS2004_B01ID
# HHIncQIS2004Eng_B01ID
# HHIncQIS2005_B01ID
# HHIncQIS2005Eng_B01ID
# HHIncQIS2006_B01ID
# HHIncQDS2006_B01ID
# HHIncQIS2006Eng_B01ID
# HHIncQDS2006Eng_B01ID
# HHIncQIS2007_B01ID
# HHIncQDS2007_B01ID
# HHIncQIS2007Eng_B01ID
# HHIncQDS2007Eng_B01ID

# %%
original_vars = ["TripStart", "TripEnd", "TripDisExSW", 
                 "TripDisIncSW" ,"TripTotalTime", "TripTravTime", 
                 "SurveyYear", "NumStages"]

# %%
# Drop any vars with suffixes

suffix_cols_to_drop = [
    col for col in merged_df_analysis.columns 
    if any(re.match(f"^{var}.*", col) and col != var for var in original_vars)  # Ensure we don't drop the exact match
]

# %%
suffix_cols_to_drop
# Out:
# ['NumStages_B01ID',
#  'TripStartHours',
#  'TripStartMinutes',
#  'TripStart_B01ID',
#  'TripStart_B02ID',
#  'TripEndHours',
#  'TripEndMinutes',
#  'TripEnd_B01ID',
#  'TripEnd_B02ID',
#  'TripDisIncSW_B01ID',
#  'TripDisExSW_B01ID',
#  'TripTotalTime_B01ID',
#  'TripTravTime_B01ID',
#  'SurveyYear_trip',
#  'SurveyYear_i',
#  'SurveyYear_x',
#  'SurveyYear_y',
#  'SurveyYear_B01ID']

# %%
merged_df_analysis = merged_df_analysis.drop(columns=suffix_cols_to_drop, axis=1)

# %%
# Exploring correlations
corr_matrix = merged_df_analysis.corr().abs()

# Print header
print(f"{'X':<25} {'Y':<25} {'Value':<10}")
print("="*60)

# Iterate through correlation matrix
for index, row in corr_matrix.iterrows():
    for col in corr_matrix.columns:
        if row[col] > 0.9 and index != col:  # Avoid self-correlations (Value = 1.0)
            print(f"{index:<25} {col:<25} {row[col]:<10.3f}")

# Start by dropping those with perfec correlation

# %% [markdown]
# Further columns to drop
#
# * SurveyYear -> TravelYear is off interest
# * TripTotalTime --> TripTravTime is of interest
# * TripDisIncSW --> TripDisExSW is of interest
# * JD --> Another variable for distance, perfectly correlated with TripDisExSW
# * JTTXSC, JOTXSC --> Highly correlated with TripTravelTime
# * TravelWeekDay_B02ID, TravelWeekDay_B03ID, -->_BO1ID is fully encoded DOW rather than WE WD
# * TravelDayTypeOld_B01ID, there is new variable for 2008 onwards

# %%
more_cols_to_drop = ["TripDisIncSW", "SurveyYear", "TripTotalTime", "JD", "JTTXSC", "JOTXSC", "TravelWeekDay_B02ID", "TravelWeekDay_B03ID", "TravelDayTypeOld_B01ID"]

# %%
# We have Travel

merged_df_analysis = merged_df_analysis.drop(columns=more_cols_to_drop, axis=1)

# %%
# Exploring correlations
corr_matrix = merged_df_analysis.corr().abs()

# Print header
print(f"{'X':<25} {'Y':<25} {'Value':<10}")
print("="*60)

# Iterate through correlation matrix
for index, row in corr_matrix.iterrows():
    for col in corr_matrix.columns:
        if row[col] > 0.9 and index != col:  # Avoid self-correlations (Value = 1.0)
            print(f"{index:<25} {col:<25} {row[col]:<10.3f}")

# Start by dropping those with perfec correlation
# Out:
# X                         Y                         Value
# ============================================================
# SeriesCall_B01ID          JJXSC                     1.000
# MainMode_B03ID            MainMode_B11ID            0.996
# MainMode_B11ID            MainMode_B03ID            0.996
# TripPurpose_B02ID         TripPurpose_B04ID         0.955
# TripPurpose_B04ID         TripPurpose_B02ID         0.955
# TripStart                 TripEnd                   0.981
# TripEnd                   TripStart                 0.981
# TripOrigGOR_B02ID         TripDestGOR_B02ID         0.979
# TripDestGOR_B02ID         TripOrigGOR_B02ID         0.979
# JJXSC                     SeriesCall_B01ID          1.000
# Interview_B01ID           BusDiffSum_B01ID          0.907
# Interview_B01ID           InterviewN_B01ID          0.988
# Interview_B01ID           EScooter_B01ID            0.993
# Interview_B01ID           PSUCountry_B01ID          0.905
# Age_B01ID                 Age_B04ID                 0.927
# Age_B04ID                 Age_B01ID                 0.927
# MarStat_B01ID             LiveWith_B02ID            0.904
# LiveWith_B02ID            MarStat_B01ID             0.904
# OrdBusFreq_B01ID          PlaneFreq_B01ID           0.951
# CoachFreq_B01ID           TrainFreq_B01ID           0.987
# CoachFreq_B01ID           TaxiCabFreq_B01ID         0.987
# TrainFreq_B01ID           CoachFreq_B01ID           0.987
# TrainFreq_B01ID           TaxiCabFreq_B01ID         0.982
# TaxiCabFreq_B01ID         CoachFreq_B01ID           0.987
# TaxiCabFreq_B01ID         TrainFreq_B01ID           0.982
# PlaneFreq_B01ID           OrdBusFreq_B01ID          0.951
# OwnCycle_B01ID            Roads_B01ID               0.953
# OwnCycle_B01ID            MainRd_B01ID              0.953
# OwnCycle_B01ID            PrivCar2_B01ID            0.949
# OwnCycle_B01ID            OrdBus2Freq_B01ID         0.934
# OwnCycle_B01ID            Coach2Freq_B01ID          0.952
# OwnCycle_B01ID            Train2Freq_B01ID          0.947
# OwnCycle_B01ID            TaxiCab2Freq_B01ID        0.948
# OwnCycle_B01ID            Plane2Freq_B01ID          0.952
# OwnCycle_B01ID            Walk2Freq_B01ID           0.927
# OwnCycle_B01ID            Ebike_B01ID               0.952
# OwnCycle_B01ID            OCSect_B01ID              0.937
# OwnCycle_B01ID            OwnCycleN_B01ID           0.949
# IntPlane_B01ID            PDrivSt_B01ID             0.931
# IntPlane_B01ID            DrivLik_B01ID             0.960
# DrivDisable_B01ID         FootOut_B01ID             0.960
# PDrivSt_B01ID             IntPlane_B01ID            0.931
# PDrivSt_B01ID             DrivLik_B01ID             0.970
# DrivLik_B01ID             IntPlane_B01ID            0.960
# DrivLik_B01ID             PDrivSt_B01ID             0.970
# PBlueBdg_B01ID            TravScW_B01ID             1.000
# PBlueBdg_B01ID            TravelDayType_B01ID       0.991
# PrbJob_B01ID              PrbNow_B01ID              0.999
# PrbNow_B01ID              PrbJob_B01ID              0.999
# PrbSame_B01ID             HowSch_B01ID              0.988
# PrbSame_B01ID             MarStN_B01ID              0.974
# PrbSame_B01ID             ResNDnM_B01ID             0.988
# DTJbMonth_B01ID           DTJbLong_B01ID            0.969
# DTJbLong_B01ID            DTJbMonth_B01ID           0.969
# EcoStat_B02ID             EcoStat_B03ID             0.972
# EcoStat_B03ID             EcoStat_B02ID             0.972
# WkHome_B01ID              PossHom_B01ID             0.966
# WkHome_B01ID              Educ_B01ID                0.965
# PossHom_B01ID             WkHome_B01ID              0.966
# PossHom_B01ID             Educ_B01ID                0.927
# PossTel_B01ID             PossComp_B01ID            0.998
# PossComp_B01ID            PossTel_B01ID             0.998
# MobDiffSum_B01ID          Accident_B01ID            0.983
# MobDiffSum_B01ID          TravDiffSum_B01ID         0.982
# BusDiffSum_B01ID          Interview_B01ID           0.907
# BusDiffSum_B01ID          InterviewN_B01ID          0.912
# BusDiffSum_B01ID          EScooter_B01ID            0.916
# BusDiffSum_B01ID          PSUCountry_B01ID          0.983
# PowWhl_B01ID              MobSct_B01ID              1.000
# MobSct_B01ID              PowWhl_B01ID              1.000
# TravScW_B01ID             PBlueBdg_B01ID            1.000
# TravScW_B01ID             TravelDayType_B01ID       0.991
# Roads_B01ID               OwnCycle_B01ID            0.953
# Roads_B01ID               MainRd_B01ID              1.000
# Roads_B01ID               PrivCar2_B01ID            0.995
# Roads_B01ID               OrdBus2Freq_B01ID         0.981
# Roads_B01ID               Coach2Freq_B01ID          0.999
# Roads_B01ID               Train2Freq_B01ID          0.994
# Roads_B01ID               TaxiCab2Freq_B01ID        0.995
# Roads_B01ID               Plane2Freq_B01ID          0.999
# Roads_B01ID               Walk2Freq_B01ID           0.972
# Roads_B01ID               Ebike_B01ID               0.999
# Roads_B01ID               OCSect_B01ID              0.983
# Roads_B01ID               OwnCycleN_B01ID           0.996
# MainRd_B01ID              OwnCycle_B01ID            0.953
# MainRd_B01ID              Roads_B01ID               1.000
# MainRd_B01ID              PrivCar2_B01ID            0.995
# MainRd_B01ID              OrdBus2Freq_B01ID         0.981
# MainRd_B01ID              Coach2Freq_B01ID          0.999
# MainRd_B01ID              Train2Freq_B01ID          0.994
# MainRd_B01ID              TaxiCab2Freq_B01ID        0.995
# MainRd_B01ID              Plane2Freq_B01ID          0.999
# MainRd_B01ID              Walk2Freq_B01ID           0.972
# MainRd_B01ID              Ebike_B01ID               0.999
# MainRd_B01ID              OCSect_B01ID              0.983
# MainRd_B01ID              OwnCycleN_B01ID           0.996
# Accident_B01ID            MobDiffSum_B01ID          0.983
# Accident_B01ID            TravDiffSum_B01ID         0.995
# Acc3Yr_B01ID              Acc12Mn_B01ID             0.998
# Acc12Mn_B01ID             Acc3Yr_B01ID              0.998
# FootOut_B01ID             DrivDisable_B01ID         0.960
# Educ_B01ID                WkHome_B01ID              0.965
# Educ_B01ID                PossHom_B01ID             0.927
# HowSch_B01ID              PrbSame_B01ID             0.988
# HowSch_B01ID              MarStN_B01ID              0.986
# HowSch_B01ID              ResNDnM_B01ID             1.000
# PrivCar_B01ID             PrbJobN_B01ID             0.918
# PrivCar_B01ID             VehSatNavN_B01ID          0.921
# PrbJobN_B01ID             PrivCar_B01ID             0.918
# FdShp_B01ID               FdDel_B01ID               0.973
# FdShp_B01ID               FdFreq_B01ID              0.979
# FdShp_B01ID               ShpEas_B01ID              0.921
# FdDel_B01ID               FdShp_B01ID               0.973
# FdDel_B01ID               FdFreq_B01ID              0.989
# FdDel_B01ID               ShpEas_B01ID              0.956
# FdFreq_B01ID              FdShp_B01ID               0.979
# FdFreq_B01ID              FdDel_B01ID               0.989
# FdFreq_B01ID              ShpEas_B01ID              0.947
# ShpEas_B01ID              FdShp_B01ID               0.921
# ShpEas_B01ID              FdDel_B01ID               0.956
# ShpEas_B01ID              FdFreq_B01ID              0.947
# MarStN_B01ID              PrbSame_B01ID             0.974
# MarStN_B01ID              HowSch_B01ID              0.986
# MarStN_B01ID              ResNDnM_B01ID             0.986
# ResNDnM_B01ID             PrbSame_B01ID             0.988
# ResNDnM_B01ID             HowSch_B01ID              1.000
# ResNDnM_B01ID             MarStN_B01ID              0.986
# CAccIdnt_B01ID            COB_B01ID                 0.974
# COB_B01ID                 CAccIdnt_B01ID            0.974
# MaritalS_B01ID            VehMakeModel_B02ID        0.914
# MaritalS_B01ID            CompanyCar_B02ID          0.916
# GenHeal_B01ID             HomeIUse_B01ID            0.992
# GenHeal_B01ID             OnGoIUse_B01ID            0.984
# GenHeal_B01ID             ElseIUse_B01ID            0.988
# GenHeal_B01ID             EdAttn4_B02ID             0.954
# HomeIUse_B01ID            GenHeal_B01ID             0.992
# HomeIUse_B01ID            OnGoIUse_B01ID            0.987
# HomeIUse_B01ID            ElseIUse_B01ID            0.987
# HomeIUse_B01ID            EdAttn4_B02ID             0.947
# OnGoIUse_B01ID            GenHeal_B01ID             0.984
# OnGoIUse_B01ID            HomeIUse_B01ID            0.987
# OnGoIUse_B01ID            ElseIUse_B01ID            0.989
# OnGoIUse_B01ID            EdAttn4_B02ID             0.938
# ElseIUse_B01ID            GenHeal_B01ID             0.988
# ElseIUse_B01ID            HomeIUse_B01ID            0.987
# ElseIUse_B01ID            OnGoIUse_B01ID            0.989
# ElseIUse_B01ID            EdAttn4_B02ID             0.945
# PracNec_B01ID             LivCit_B01ID              0.993
# LivCit_B01ID              PracNec_B01ID             0.993
# EdAttn4_B02ID             GenHeal_B01ID             0.954
# EdAttn4_B02ID             HomeIUse_B01ID            0.947
# EdAttn4_B02ID             OnGoIUse_B01ID            0.938
# EdAttn4_B02ID             ElseIUse_B01ID            0.945
# NTrnsat_B01ID             RelTrain_B01ID            0.997
# NTrnsat_B01ID             FrqTrain_B01ID            0.996
# NTrnsat_B01ID             NSatServ_B01ID            0.980
# NTrnsat_B01ID             NReliBus_B01ID            0.960
# NTrnsat_B01ID             NFrqBus_B01ID             0.961
# NTrnsat_B01ID             SRNRdSat_B01ID            0.987
# NTrnsat_B01ID             LocRdSat_B01ID            0.988
# NTrnsat_B01ID             Ncyclane_B01ID            0.987
# NTrnsat_B01ID             WalkProv_B01ID            0.988
# RelTrain_B01ID            NTrnsat_B01ID             0.997
# RelTrain_B01ID            FrqTrain_B01ID            0.997
# RelTrain_B01ID            NSatServ_B01ID            0.980
# RelTrain_B01ID            NReliBus_B01ID            0.960
# RelTrain_B01ID            NFrqBus_B01ID             0.961
# RelTrain_B01ID            SRNRdSat_B01ID            0.987
# RelTrain_B01ID            LocRdSat_B01ID            0.988
# RelTrain_B01ID            Ncyclane_B01ID            0.986
# RelTrain_B01ID            WalkProv_B01ID            0.987
# FrqTrain_B01ID            NTrnsat_B01ID             0.996
# FrqTrain_B01ID            RelTrain_B01ID            0.997
# FrqTrain_B01ID            NSatServ_B01ID            0.979
# FrqTrain_B01ID            NReliBus_B01ID            0.960
# FrqTrain_B01ID            NFrqBus_B01ID             0.960
# FrqTrain_B01ID            SRNRdSat_B01ID            0.987
# FrqTrain_B01ID            LocRdSat_B01ID            0.987
# FrqTrain_B01ID            Ncyclane_B01ID            0.986
# FrqTrain_B01ID            WalkProv_B01ID            0.987
# NSatServ_B01ID            NTrnsat_B01ID             0.980
# NSatServ_B01ID            RelTrain_B01ID            0.980
# NSatServ_B01ID            FrqTrain_B01ID            0.979
# NSatServ_B01ID            NReliBus_B01ID            0.974
# NSatServ_B01ID            NFrqBus_B01ID             0.974
# NSatServ_B01ID            SRNRdSat_B01ID            0.982
# NSatServ_B01ID            LocRdSat_B01ID            0.982
# NSatServ_B01ID            Ncyclane_B01ID            0.982
# NSatServ_B01ID            WalkProv_B01ID            0.982
# NReliBus_B01ID            NTrnsat_B01ID             0.960
# NReliBus_B01ID            RelTrain_B01ID            0.960
# NReliBus_B01ID            FrqTrain_B01ID            0.960
# NReliBus_B01ID            NSatServ_B01ID            0.974
# NReliBus_B01ID            NFrqBus_B01ID             0.998
# NReliBus_B01ID            SRNRdSat_B01ID            0.963
# NReliBus_B01ID            LocRdSat_B01ID            0.963
# NReliBus_B01ID            Ncyclane_B01ID            0.963
# NReliBus_B01ID            WalkProv_B01ID            0.962
# NFrqBus_B01ID             NTrnsat_B01ID             0.961
# NFrqBus_B01ID             RelTrain_B01ID            0.961
# NFrqBus_B01ID             FrqTrain_B01ID            0.960
# NFrqBus_B01ID             NSatServ_B01ID            0.974
# NFrqBus_B01ID             NReliBus_B01ID            0.998
# NFrqBus_B01ID             SRNRdSat_B01ID            0.963
# NFrqBus_B01ID             LocRdSat_B01ID            0.964
# NFrqBus_B01ID             Ncyclane_B01ID            0.964
# NFrqBus_B01ID             WalkProv_B01ID            0.963
# SRNRdSat_B01ID            NTrnsat_B01ID             0.987
# SRNRdSat_B01ID            RelTrain_B01ID            0.987
# SRNRdSat_B01ID            FrqTrain_B01ID            0.987
# SRNRdSat_B01ID            NSatServ_B01ID            0.982
# SRNRdSat_B01ID            NReliBus_B01ID            0.963
# SRNRdSat_B01ID            NFrqBus_B01ID             0.963
# SRNRdSat_B01ID            LocRdSat_B01ID            0.993
# SRNRdSat_B01ID            Ncyclane_B01ID            0.989
# SRNRdSat_B01ID            WalkProv_B01ID            0.991
# LocRdSat_B01ID            NTrnsat_B01ID             0.988
# LocRdSat_B01ID            RelTrain_B01ID            0.988
# LocRdSat_B01ID            FrqTrain_B01ID            0.987
# LocRdSat_B01ID            NSatServ_B01ID            0.982
# LocRdSat_B01ID            NReliBus_B01ID            0.963
# LocRdSat_B01ID            NFrqBus_B01ID             0.964
# LocRdSat_B01ID            SRNRdSat_B01ID            0.993
# LocRdSat_B01ID            Ncyclane_B01ID            0.990
# LocRdSat_B01ID            WalkProv_B01ID            0.992
# Ncyclane_B01ID            NTrnsat_B01ID             0.987
# Ncyclane_B01ID            RelTrain_B01ID            0.986
# Ncyclane_B01ID            FrqTrain_B01ID            0.986
# Ncyclane_B01ID            NSatServ_B01ID            0.982
# Ncyclane_B01ID            NReliBus_B01ID            0.963
# Ncyclane_B01ID            NFrqBus_B01ID             0.964
# Ncyclane_B01ID            SRNRdSat_B01ID            0.989
# Ncyclane_B01ID            LocRdSat_B01ID            0.990
# Ncyclane_B01ID            WalkProv_B01ID            0.991
# WalkProv_B01ID            NTrnsat_B01ID             0.988
# WalkProv_B01ID            RelTrain_B01ID            0.987
# WalkProv_B01ID            FrqTrain_B01ID            0.987
# WalkProv_B01ID            NSatServ_B01ID            0.982
# WalkProv_B01ID            NReliBus_B01ID            0.962
# WalkProv_B01ID            NFrqBus_B01ID             0.963
# WalkProv_B01ID            SRNRdSat_B01ID            0.991
# WalkProv_B01ID            LocRdSat_B01ID            0.992
# WalkProv_B01ID            Ncyclane_B01ID            0.991
# YNWkSAM_B01ID             YNWkSBM_B01ID             1.000
# YNWkSAM_B01ID             YNWkScM_B01ID             1.000
# YNWkSAM_B01ID             EnWkScM_B01ID             1.000
# YNWkSAM_B01ID             PHVuse_B01ID              0.998
# YNWkSAM_B01ID             BikeTyp2_B01ID            0.947
# YNWkSAM_B01ID             TypeVcl3_B01ID            0.997
# YNWkSAM_B01ID             AutMan_B01ID              0.996
# Plane2Freq_B01ID          OCSect_B01ID              0.983
# Plane2Freq_B01ID          OwnCycleN_B01ID           0.995
# Walk2Freq_B01ID           OwnCycle_B01ID            0.927
# Walk2Freq_B01ID           Roads_B01ID               0.972
# Walk2Freq_B01ID           MainRd_B01ID              0.972
# Walk2Freq_B01ID           PrivCar2_B01ID            0.968
# Walk2Freq_B01ID           OrdBus2Freq_B01ID         0.955
# Walk2Freq_B01ID           Coach2Freq_B01ID          0.972
# Walk2Freq_B01ID           Train2Freq_B01ID          0.969
# Walk2Freq_B01ID           TaxiCab2Freq_B01ID        0.968
# Walk2Freq_B01ID           Plane2Freq_B01ID          0.972
# Walk2Freq_B01ID           Ebike_B01ID               0.972
# Walk2Freq_B01ID           OCSect_B01ID              0.956
# Walk2Freq_B01ID           OwnCycleN_B01ID           0.971
# Ebike_B01ID               OwnCycle_B01ID            0.952
# Ebike_B01ID               Roads_B01ID               0.999
# Ebike_B01ID               MainRd_B01ID              0.999
# Ebike_B01ID               PrivCar2_B01ID            0.995
# Ebike_B01ID               OrdBus2Freq_B01ID         0.980
# Ebike_B01ID               Coach2Freq_B01ID          0.998
# Ebike_B01ID               Train2Freq_B01ID          0.994
# Ebike_B01ID               TaxiCab2Freq_B01ID        0.994
# Ebike_B01ID               Plane2Freq_B01ID          0.998
# Ebike_B01ID               Walk2Freq_B01ID           0.972
# Ebike_B01ID               OCSect_B01ID              0.983
# Ebike_B01ID               OwnCycleN_B01ID           0.996
# LackComp_B01ID            LeftOut_B01ID             0.998
# LackComp_B01ID            Isolated_B01ID            0.998
# LackComp_B01ID            Lonely_B01ID              0.991
# LeftOut_B01ID             LackComp_B01ID            0.998
# LeftOut_B01ID             Isolated_B01ID            0.999
# LeftOut_B01ID             Lonely_B01ID              0.991
# Isolated_B01ID            LackComp_B01ID            0.998
# Isolated_B01ID            LeftOut_B01ID             0.999
# Isolated_B01ID            Lonely_B01ID              0.991
# Lonely_B01ID              LackComp_B01ID            0.991
# Lonely_B01ID              LeftOut_B01ID             0.991
# Lonely_B01ID              Isolated_B01ID            0.991
# OCSect_B01ID              OwnCycle_B01ID            0.937
# OCSect_B01ID              Roads_B01ID               0.983
# OCSect_B01ID              MainRd_B01ID              0.983
# OCSect_B01ID              PrivCar2_B01ID            0.979
# OCSect_B01ID              OrdBus2Freq_B01ID         0.965
# OCSect_B01ID              Coach2Freq_B01ID          0.982
# OCSect_B01ID              Train2Freq_B01ID          0.977
# OCSect_B01ID              TaxiCab2Freq_B01ID        0.978
# OCSect_B01ID              Plane2Freq_B01ID          0.983
# OCSect_B01ID              Walk2Freq_B01ID           0.956
# OCSect_B01ID              Ebike_B01ID               0.983
# OCSect_B01ID              OwnCycleN_B01ID           0.979
# OwnCycleN_B01ID           OwnCycle_B01ID            0.949
# OwnCycleN_B01ID           Roads_B01ID               0.996
# OwnCycleN_B01ID           MainRd_B01ID              0.996
# OwnCycleN_B01ID           PrivCar2_B01ID            0.992
# OwnCycleN_B01ID           OrdBus2Freq_B01ID         0.975
# OwnCycleN_B01ID           Coach2Freq_B01ID          0.995
# OwnCycleN_B01ID           Train2Freq_B01ID          0.991
# OwnCycleN_B01ID           TaxiCab2Freq_B01ID        0.991
# OwnCycleN_B01ID           Plane2Freq_B01ID          0.995
# OwnCycleN_B01ID           Walk2Freq_B01ID           0.971
# OwnCycleN_B01ID           Ebike_B01ID               0.996
# OwnCycleN_B01ID           OCSect_B01ID              0.979
# InterviewN_B01ID          Interview_B01ID           0.988
# InterviewN_B01ID          BusDiffSum_B01ID          0.912
# InterviewN_B01ID          EScooter_B01ID            0.996
# InterviewN_B01ID          PSUCountry_B01ID          0.909
# EScooter_B01ID            Interview_B01ID           0.993
# EScooter_B01ID            BusDiffSum_B01ID          0.916
# EScooter_B01ID            InterviewN_B01ID          0.996
# EScooter_B01ID            PSUCountry_B01ID          0.913
# TravDiffSum_B01ID         MobDiffSum_B01ID          0.982
# TravDiffSum_B01ID         Accident_B01ID            0.995
# VehMakeModel_B02ID        MaritalS_B01ID            0.914
# VehWeekMileage_B01ID      VehEligMileage_B01ID      0.994
# VehEligMileage_B01ID      VehWeekMileage_B01ID      0.994
# VehMilesOutGB_B01ID       VehPurpOutGB_B01ID        0.965
# VehPurpOutGB_B01ID        VehMilesOutGB_B01ID       0.965
# CompanyCar_B02ID          MaritalS_B01ID            0.916
# VehBusMile_B01ID          VehPriMile_B01ID          0.918
# VehPriMile_B01ID          VehBusMile_B01ID          0.918
# VehSatNavN_B01ID          PrivCar_B01ID             0.921
# BikeTyp2_B01ID            YNWkSAM_B01ID             0.947
# BikeTyp2_B01ID            YNWkSBM_B01ID             0.947
# BikeTyp2_B01ID            YNWkScM_B01ID             0.947
# BikeTyp2_B01ID            EnWkScM_B01ID             0.947
# BikeTyp2_B01ID            PHVuse_B01ID              0.945
# BikeTyp2_B01ID            TypeVcl3_B01ID            0.949
# BikeTyp2_B01ID            AutMan_B01ID              0.932
# TypeVcl3_B01ID            YNWkSAM_B01ID             0.997
# TypeVcl3_B01ID            YNWkSBM_B01ID             0.997
# TypeVcl3_B01ID            YNWkScM_B01ID             0.997
# TypeVcl3_B01ID            EnWkScM_B01ID             0.997
# TypeVcl3_B01ID            PHVuse_B01ID              0.995
# TypeVcl3_B01ID            BikeTyp2_B01ID            0.949
# TypeVcl3_B01ID            AutMan_B01ID              0.989
# AutMan_B01ID              YNWkSAM_B01ID             0.996
# AutMan_B01ID              YNWkSBM_B01ID             0.996
# AutMan_B01ID              YNWkScM_B01ID             0.996
# AutMan_B01ID              EnWkScM_B01ID             0.996
# AutMan_B01ID              PHVuse_B01ID              0.994
# AutMan_B01ID              BikeTyp2_B01ID            0.932
# AutMan_B01ID              TypeVcl3_B01ID            0.989
# PSUCountry_B01ID          Interview_B01ID           0.905
# PSUCountry_B01ID          BusDiffSum_B01ID          0.983
# PSUCountry_B01ID          InterviewN_B01ID          0.909
# PSUCountry_B01ID          EScooter_B01ID            0.913
# TravelDayType_B01ID       PBlueBdg_B01ID            0.991
# TravelDayType_B01ID       TravScW_B01ID             0.991

# %%
# encoding num trips
num_trips_mapping = dict(zip(merged_df_analysis.groupby("IndividualID_x")["JourSeq"].max().index, merged_df_analysis.groupby("IndividualID_x")["JourSeq"].max().values))
merged_df_analysis["NumTrips"] = merged_df_analysis["IndividualID_x"].map(num_trips_mapping)
# Out:
# /tmp/ipykernel_9649/1483458916.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df_analysis["NumTrips"] = merged_df_analysis["IndividualID_x"].map(num_trips_mapping)

# %%
# Making a trip purpouse mapping

trip_purpose_mapping = {
    1: "Work", 2: "Other", 3: "Other", 4: "Other", 5: "Other",
    6: "Other", 7: "Other", 8: "Other", 9: "Other", 10: "Other",
    11: "Other", 12: "Other", 13: "Other", 14: "Other", 15: "Other",
    16: "Other", 17: "Other", 18: "Other", 19: "Other", 20: "Other",
    21: "Other", 22: "Other", 23: "Home",
}

# %%
# Removing Values for  Dead or Na

merged_df_analysis = merged_df_analysis[~merged_df_analysis["TripPurpFrom_B01ID"].isin([-8,-10])]
merged_df_analysis = merged_df_analysis[~merged_df_analysis["TripPurpTo_B01ID"].isin([-8,-10])]

# %%
merged_df_analysis["TripPurpFrom_B01ID"] = merged_df_analysis["TripPurpFrom_B01ID"].map(trip_purpose_mapping)
merged_df_analysis["TripPurpTo_B01ID"] = merged_df_analysis["TripPurpTo_B01ID"].map(trip_purpose_mapping)

# %%
merged_df_analysis["TripType"] = list(zip(merged_df_analysis["TripPurpFrom_B01ID"], merged_df_analysis["TripPurpTo_B01ID"]))

# %%
trip_type_mapping = {}

for i,type in enumerate(merged_df_analysis["TripType"].unique()):
    trip_type_mapping[type] = i
    
print(f"Trip type mapping")
for k,v in trip_type_mapping.items():
    print(f"{k}: {v}")
# Out:
# Trip type mapping
# ('Other', 'Home'): 0
# ('Home', 'Other'): 1
# ('Work', 'Home'): 2
# ('Work', 'Other'): 3
# ('Home', 'Work'): 4
# ('Other', 'Other'): 5
# ('Other', 'Work'): 6

# %%
merged_df_analysis["TripType"] = merged_df_analysis["TripType"].map(trip_type_mapping)

# %%
for k,v in merged_df_analysis.dtypes.items():
    if v == "object":
        print(k, v)

merged_df_analysis.drop(columns=["TripPurpFrom_B01ID", "TripPurpTo_B01ID"], axis=1, inplace=True, errors="ignore")
# Out:
# TripPurpFrom_B01ID object
# TripPurpTo_B01ID object

# %%
vars_of_interest = ["TripStart", "TripEnd", "TripDisExSW", ]

# %%
merged_df_analysis["TripDisExSW"]

# %%
# Predicting trip distance

corr_matrix["TripDisExSW"].sort_values(ascending=False)
# Out:
# TripDisExSW            1.000000
# TripTravTime           0.897463
# VehAnMileage           0.215814
# VehAnMileage_B01ID     0.191324
# IndIncome2002_B02ID    0.119539
#                          ...
# MainMode_B04ID              NaN
# DrivLic_B02ID               NaN
# SchDly_B01ID                NaN
# SchTrav_B01ID               NaN
# SchAcc_B01ID                NaN
# Name: TripDisExSW, Length: 239, dtype: float64

# %%
## Saving to pickle next step is to try and predict Distance

merged_df_analysis.to_pickle("/home/trapfishscott/Cambridge24.25/D200_ML_econ/ProblemSets/Project/data/merged_df_analysis.pkl")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
